# %%
pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in c:\users\msi\appdata\roaming\python\python311\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\msi\appdata\roaming\python\python311\site-packages (from nltk) (8.1.3)
# Requirement already satisfied: joblib in c:\users\msi\appdata\roaming\python\python311\site-packages (from nltk) (1.1.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\msi\appdata\roaming\python\python311\site-packages (from nltk) (2023.5.5)
# Requirement already satisfied: tqdm in c:\users\msi\appdata\roaming\python\python311\site-packages (from nltk) (4.65.0)
# Requirement already satisfied: colorama in c:\users\msi\appdata\roaming\python\python311\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip list
# Out:
# Package                                  VersionNote: you may need to restart the kernel to use updated packages.
#
# ---------------------------------------- -----------
# absl-py                                  1.4.0
# aiofiles                                 23.1.0
# aiohttp                                  3.8.4
# aiosignal                                1.3.1
# altair                                   5.0.1
# anyio                                    3.7.0
# appdirs                                  1.4.4
# APScheduler                              3.6.3
# argon2-cffi                              21.3.0
# argon2-cffi-bindings                     21.2.0
# arrow                                    1.2.3
# asttokens                                2.2.1
# astunparse                               1.6.3
# async-timeout                            4.0.2
# asyncer                                  0.0.2
# attrs                                    23.1.0
# auth0-python                             4.2.0
# autopep8                                 2.0.2
# backcall                                 0.2.0
# backoff                                  2.2.1
# beautifulsoup4                           4.11.2
# bidict                                   0.22.1
# bleach                                   6.0.0
# blinker                                  1.6.2
# boto3                                    1.28.30
# botocore                                 1.31.30
# bs4                                      0.0.1
# cachetools                               4.2.2
# certifi                                  2022.12.7
# cffi                                     1.15.1
# chainlit                                 0.4.0
# chardet                                  5.2.0
# charset-normalizer                       3.0.1
# click                                    8.1.3
# colorama                                 0.4.6
# comm                                     0.1.2
# comtypes                                 1.1.14
# constants                                0.6.0
# contourpy                                1.0.7
# cors                                     1.0.1
# cryptography                             41.0.1
# cvzone                                   1.5.6
# cycler                                   0.11.0
# dacite                                   1.8.1
# dataclasses-json                         0.5.8
# debugpy                                  1.6.6
# decorator                                4.4.2
# defusedxml                               0.7.1
# Deprecated                               1.2.14
# distlib                                  0.3.6
# dnspython                                2.3.0
# et-xmlfile                               1.1.0
# executing                                1.2.0
# fastapi                                  0.96.1
# fastapi-socketio                         0.0.10
# fastjsonschema                           2.17.1
# filelock                                 3.12.0
# Flask                                    2.2.3
# Flask-Cors                               3.0.10
# flatbuffers                              23.5.26
# fonttools                                4.39.2
# fqdn                                     1.5.1
# frozendict                               2.3.8
# frozenlist                               1.3.3
# future                                   0.18.3
# gast                                     0.4.0
# gevent                                   22.10.2
# gitdb                                    4.0.10
# GitPython                                3.1.32
# google-auth                              2.19.1
# google-auth-oauthlib                     1.0.0
# google-pasta                             0.2.0
# googleapis-common-protos                 1.59.1
# greenlet                                 2.0.2
# grpcio                                   1.54.2
# gTTS                                     2.3.1
# h11                                      0.14.0
# h5py                                     3.8.0
# html5lib                                 1.1
# htmlmin                                  0.1.12
# huepy                                    1.2.1
# idna                                     3.4
# ImageHash                                4.3.1
# imageio                                  2.31.1
# imageio-ffmpeg                           0.4.8
# importlib-metadata                       6.0.1
# iniconfig                                2.0.0
# instabot                                 0.117.0
# ipykernel                                6.20.2
# ipython                                  8.9.0
# ipython-genutils                         0.2.0
# ipywidgets                               8.0.6
# isoduration                              20.11.0
# itsdangerous                             2.1.2
# jax                                      0.4.12
# jedi                                     0.18.2
# Jinja2                                   3.1.2
# jmespath                                 1.0.1
# joblib                                   1.1.1
# jsonpointer                              2.3
# jsonschema                               4.17.3
# jupyter                                  1.0.0
# jupyter_client                           8.0.2
# jupyter-console                          6.6.3
# jupyter_core                             5.2.0
# jupyter-events                           0.6.3
# jupyter_server                           2.6.0
# jupyter_server_terminals                 0.4.4
# jupyterlab-pygments                      0.2.2
# jupyterlab-widgets                       3.0.7
# keras                                    2.12.0
# kiwisolver                               1.4.4
# langchain                                0.0.205
# langchainplus-sdk                        0.0.11
# libclang                                 16.0.0
# lxml                                     4.9.3
# Markdown                                 3.4.3
# markdown-it-py                           3.0.0
# MarkupSafe                               2.1.2
# marshmallow                              3.19.0
# marshmallow-enum                         1.5.1
# matplotlib                               3.7.1
# matplotlib-inline                        0.1.6
# mdurl                                    0.1.2
# mediapipe                                0.10.3
# missingno                                0.5.2
# mistune                                  2.0.5
# ml-dtypes                                0.2.0
# mock                                     5.1.0
# moviepy                                  1.0.3
# mpmath                                   1.3.0
# multidict                                6.0.4
# multimethod                              1.9.1
# multitasking                             0.0.11
# multithreading                           0.2.0
# mypy-extensions                          1.0.0
# nbclassic                                1.0.0
# nbclient                                 0.8.0
# nbconvert                                7.5.0
# nbformat                                 5.9.0
# nest-asyncio                             1.5.6
# networkx                                 3.1
# nltk                                     3.8.1
# notebook                                 6.5.4
# notebook_shim                            0.2.3
# numexpr                                  2.8.4
# numpy                                    1.25.0
# oauthlib                                 3.2.2
# openai                                   0.27.8
# openapi-schema-pydantic                  1.2.4
# opencv-contrib-python                    4.8.0.76
# opencv-python                            4.8.0.76
# openpyxl                                 3.1.2
# opentelemetry-api                        1.18.0
# opentelemetry-exporter-otlp              1.18.0
# opentelemetry-exporter-otlp-proto-common 1.18.0
# opentelemetry-exporter-otlp-proto-grpc   1.18.0
# opentelemetry-exporter-otlp-proto-http   1.18.0
# opentelemetry-instrumentation            0.39b0
# opentelemetry-proto                      1.18.0
# opentelemetry-sdk                        1.18.0
# opentelemetry-semantic-conventions       0.39b0
# opt-einsum                               3.3.0
# overrides                                7.3.1
# packaging                                23.0
# pandas                                   2.0.2
# pandas-profiling                         3.2.0
# pandocfilters                            1.5.0
# parso                                    0.8.3
# patsy                                    0.5.3
# phik                                     0.12.3
# pickleshare                              0.7.5
# Pillow                                   9.4.0
# pip                                      23.3.1
# platformdirs                             3.2.0
# pluggy                                   1.2.0
# proglog                                  0.1.10
# prometheus-client                        0.17.0
# prompt-toolkit                           3.0.36
# protobuf                                 3.20.3
# psutil                                   5.9.4
# pure-eval                                0.2.2
# pyarrow                                  12.0.1
# pyasn1                                   0.5.0
# pyasn1-modules                           0.3.0
# PyAudio                                  0.2.13
# pycodestyle                              2.10.0
# pycparser                                2.21
# pydantic                                 1.10.9
# pydeck                                   0.8.0
# pydub                                    0.25.1
# pygame                                   2.5.1
# Pygments                                 2.14.0
# PyJWT                                    2.7.0
# pymongo                                  3.11.0
# Pympler                                  1.0.1
# pyparsing                                3.0.9
# pypiwin32                                223
# pyrsistent                               0.19.3
# PySocks                                  1.7.1
# pytest                                   7.4.0
# python-dateutil                          2.8.2
# python-dotenv                            1.0.0
# python-engineio                          4.4.1
# python-graphql-client                    0.4.3
# python-json-logger                       2.0.7
# python-socketio                          5.8.0
# python-telegram-bot                      13.7
# pyttsx3                                  2.90
# pytz                                     2022.7.1
# pytz-deprecation-shim                    0.1.0.post0
# PyWavelets                               1.4.1
# pywin32                                  305
# pywinpty                                 2.0.10
# PyYAML                                   6.0
# pyzmq                                    25.0.0
# qtconsole                                5.4.3
# QtPy                                     2.3.1
# regex                                    2023.5.5
# requests                                 2.31.0
# requests-file                            1.5.1
# requests-oauthlib                        1.3.1
# requests-toolbelt                        1.0.0
# responses                                0.23.3
# rfc3339-validator                        0.1.4
# rfc3986-validator                        0.1.1
# rich                                     13.5.0
# rsa                                      4.9
# s3transfer                               0.6.2
# schedule                                 1.2.0
# scikit-learn                             1.2.2
# scipy                                    1.10.1
# seaborn                                  0.12.2
# Send2Trash                               1.8.2
# setuptools                               65.5.0
# six                                      1.16.0
# smmap                                    5.0.0
# sniffio                                  1.3.0
# sounddevice                              0.4.6
# soupsieve                                2.4
# SpeechRecognition                        3.10.0
# SQLAlchemy                               2.0.16
# stack-data                               0.6.2
# starlette                                0.27.0
# statsmodels                              0.14.0
# streamlit                                1.25.0
# sympy                                    1.12
# syncer                                   2.0.3
# tangled-up-in-unicode                    0.2.0
# tenacity                                 8.2.2
# tensorboard                              2.12.3
# tensorboard-data-server                  0.7.0
# tensorflow                               2.12.0
# tensorflow-estimator                     2.12.0
# tensorflow-intel                         2.12.0
# tensorflow-io-gcs-filesystem             0.31.0
# termcolor                                2.3.0
# terminado                                0.17.1
# threadpoolctl                            3.1.0
# tinycss2                                 1.2.1
# tldextract                               3.4.0
# toml                                     0.10.2
# tomli                                    2.0.1
# toolz                                    0.12.0
# torch                                    2.0.1
# tornado                                  6.2
# tqdm                                     4.65.0
# traitlets                                5.9.0
# typeguard                                2.13.3
# types-PyYAML                             6.0.12.11
# typing_extensions                        4.6.3
# typing-inspect                           0.9.0
# tzdata                                   2023.3
# tzlocal                                  4.3.1
# uptrace                                  1.18.0
# uri-template                             1.2.0
# urllib3                                  1.26.14
# uvicorn                                  0.22.0
# validators                               0.20.0
# virtualenv                               20.22.0
# visions                                  0.7.5
# watchdog                                 3.0.0
# watchfiles                               0.19.0
# wcwidth                                  0.2.6
# webcolors                                1.13
# webencodings                             0.5.1
# websocket-client                         1.5.3
# websockets                               11.0.3
# Werkzeug                                 2.2.3
# wheel                                    0.40.0
# widgetsnbextension                       4.0.7
# wordcloud                                1.9.2
# wrapt                                    1.14.1
# xlwt                                     1.3.0
# yarl                                     1.9.2
# ydata-profiling                          4.2.0
# yfinance                                 0.2.26
# zipp                                     3.15.0
# zope.event                               4.6
# zope.interface                           5.5.2

# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction import text
from sklearn.metrics.pairwise import cosine_similarity

# %%
netflix_df=pd.read_csv('netflixData.csv')
print(netflix_df.head(5))
# Out:
#                                 Show Id                          Title  \
# 0  cc1b6ed9-cf9e-4057-8303-34577fb54477                       (Un)Well
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2  b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
# 3  b6611af0-f53c-4a08-9ffa-9716dc57eb9c                       #blackAF
# 4  7f2d4170-bab8-4d75-adc2-197f7124c070               #cats_the_mewvie
#
#                                          Description  \
# 0  This docuseries takes a deep dive into the luc...
# 1  As a grisly virus rampages a city, a lone man ...
# 2  Through her diary, Anne Frank's story is retol...
# 3  Kenya Barris and his family navigate relations...
# 4  This pawesome documentary explores how our fel...
#
#                       Director  \
# 0                          NaN
# 1                       Cho Il
# 2  Sabina Fedeli, Anna Migotto
# 3                          NaN
# 4             Michael Margolis
#
#                                            Genres  \
# 0                                      Reality TV
# 1  Horror Movies, International Movies, Thrillers
# 2             Documentaries, International Movies
# 3                                     TV Comedies
# 4             Documentaries, International Movies
#
#                                                 Cast Production Country  \
# 0                                                NaN      United States
# 1                           Yoo Ah-in, Park Shin-hye        South Korea
# 2                        Helen Mirren, Gengher Gatti              Italy
# 3  Kenya Barris, Rashida Jones, Iman Benson, Genn...      United States
# 4                                                NaN             Canada
#
#    Release Date Rating  Duration Imdb Score Content Type         Date Added
# 0        2020.0  TV-MA  1 Season     6.6/10      TV Show                NaN
# 1        2020.0  TV-MA    99 min     6.2/10        Movie  September 8, 2020
# 2        2019.0  TV-14    95 min     6.4/10        Movie       July 1, 2020
# 3        2020.0  TV-MA  1 Season     6.6/10      TV Show                NaN
# 4        2020.0  TV-14    90 min     5.1/10        Movie   February 5, 2020

# %% [markdown]
# Start Data Cleaning in this

# %%
netflix_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5967 entries, 0 to 5966
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Show Id             5967 non-null   object
#  1   Title               5967 non-null   object
#  2   Description         5967 non-null   object
#  3   Director            3903 non-null   object
#  4   Genres              5967 non-null   object
#  5   Cast                5437 non-null   object
#  6   Production Country  5408 non-null   object
#  7   Release Date        5964 non-null   float64
#  8   Rating              5963 non-null   object
#  9   Duration            5964 non-null   object
#  10  Imdb Score          5359 non-null   object
#  11  Content Type        5967 non-null   object
#  12  Date Added          4632 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 606.2+ KB

# %%
print(netflix_df.isnull().sum())
# Out:
# Show Id                  0
# Title                    0
# Description              0
# Director              2064
# Genres                   0
# Cast                   530
# Production Country     559
# Release Date             3
# Rating                   4
# Duration                 3
# Imdb Score             608
# Content Type             0
# Date Added            1335
# dtype: int64

# %%
required_nf_df=netflix_df[["Title","Description","Content Type","Genres"]]
required_nf_df.head()
# Out:
#                            Title  \
# 0                       (Un)Well
# 1                         #Alive
# 2  #AnneFrank - Parallel Stories
# 3                       #blackAF
# 4               #cats_the_mewvie
#
#                                          Description Content Type  \
# 0  This docuseries takes a deep dive into the luc...      TV Show
# 1  As a grisly virus rampages a city, a lone man ...        Movie
# 2  Through her diary, Anne Frank's story is retol...        Movie
# 3  Kenya Barris and his family navigate relations...      TV Show
# 4  This pawesome documentary explores how our fel...        Movie
#
#                                            Genres
# 0                                      Reality TV
# 1  Horror Movies, International Movies, Thrillers
# 2             Documentaries, International Movies
# 3                                     TV Comedies
# 4             Documentaries, International Movies

# %% [markdown]
# DROp the null values

# %%
required_nf_df.dropna()
# Out:
#                               Title  \
# 0                          (Un)Well
# 1                            #Alive
# 2     #AnneFrank - Parallel Stories
# 3                          #blackAF
# 4                  #cats_the_mewvie
# ...                             ...
# 5962                      الف مبروك
# 5963                   دفعة القاهرة
# 5964                           海的儿子
# 5965                        반드시 잡는다
# 5966            최강전사 미니특공대 : 영웅의 탄생
#
#                                             Description Content Type  \
# 0     This docuseries takes a deep dive into the luc...      TV Show
# 1     As a grisly virus rampages a city, a lone man ...        Movie
# 2     Through her diary, Anne Frank's story is retol...        Movie
# 3     Kenya Barris and his family navigate relations...      TV Show
# 4     This pawesome documentary explores how our fel...        Movie
# ...                                                 ...          ...
# 5962  On his wedding day, an arrogant, greedy accoun...        Movie
# 5963  A group of women leaves Kuwait to attend unive...      TV Show
# 5964  Two brothers start a new life in Singapore, wh...      TV Show
# 5965  After people in his town start turning up dead...        Movie
# 5966  Miniforce, a special task force of elite range...        Movie
#
#                                               Genres
# 0                                         Reality TV
# 1     Horror Movies, International Movies, Thrillers
# 2                Documentaries, International Movies
# 3                                        TV Comedies
# 4                Documentaries, International Movies
# ...                                              ...
# 5962          Comedies, Dramas, International Movies
# 5963               International TV Shows, TV Dramas
# 5964               International TV Shows, TV Dramas
# 5965         Dramas, International Movies, Thrillers
# 5966                        Children & Family Movies
#
# [5967 rows x 4 columns]

# %%
required_nf_df.count()
# Out:
# Title           5967
# Description     5967
# Content Type    5967
# Genres          5967
# dtype: int64

# %%
required_nf_df.count()
# Out:
# Title           5967
# Description     5967
# Content Type    5967
# Genres          5967
# dtype: int64

# %%
# Clean the dataset
import nltk

# %%
nltk.download('stopwords')
stemmer = nltk.SnowballStemmer("english")
from nltk.corpus import stopwords

import string
stopword = set(stopwords.words('english'))
# Out:
# [nltk_data] Error loading stopwords: <urlopen error [WinError 10060] A
# [nltk_data]     connection attempt failed because the connected party
# [nltk_data]     did not properly respond after a period of time, or
# [nltk_data]     established connection failed because connected host
# [nltk_data]     has failed to respond>
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\nltk\corpus\util.py:84, in LazyCorpusLoader.__load(self)
#      83 try:
# ---> 84     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85 except LookupError:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\nltk\data.py:583, in find(resource_name, paths)
#     582 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/stopwords.zip/stopwords/
#
#   Searched in:
#     - 'C:\\Users\\msi/nltk_data'
#     - 'c:\\Program Files\\Python311\\nltk_data'
#     - 'c:\\Program Files\\Python311\\share\\nltk_data'
#     - 'c:\\Program Files\\Python311\\lib\\nltk_data'
#     - 'C:\\Users\\msi\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# d:\Python Projects\Movie Recommendation for netflix\netflix.ipynb Cell 14 line 6
#       <a href='vscode-notebook-cell:/d%3A/Python%20Projects/Movie%20Recommendation%20for%20netflix/netflix.ipynb#X21sZmlsZQ%3D%3D?line=2'>3</a> from nltk.corpus import stopwords
#       <a href='vscode-notebook-cell:/d%3A/Python%20Projects/Movie%20Recommendation%20for%20netflix/netflix.ipynb#X21sZmlsZQ%3D%3D?line=4'>5</a> import string
# ----> <a href='vscode-notebook-cell:/d%3A/Python%20Projects/Movie%20Recommendation%20for%20netflix/netflix.ipynb#X21sZmlsZQ%3D%3D?line=5'>6</a> stopword = set(stopwords.words('english'))
#
# File ~\AppData\Roaming\Python\Python311\site-packages\nltk\corpus\util.py:121, in LazyCorpusLoader.__getattr__(self, attr)
#     118 if attr == "__bases__":
#     119     raise AttributeError("LazyCorpusLoader object has no attribute '__bases__'")
# --> 121 self.__load()
#     122 # This looks circular, but its not, since __load() changes our
#     123 # __class__ to something new:
#     124 return getattr(self, attr)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\nltk\corpus\util.py:86, in LazyCorpusLoader.__load(self)
#      84             root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85         except LookupError:
# ---> 86             raise e
#      88 # Load the corpus.
#      89 corpus = self.__reader_cls(root, *self.__args, **self.__kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\nltk\corpus\util.py:81, in LazyCorpusLoader.__load(self)
#      79 else:
#      80     try:
# ---> 81         root = nltk.data.find(f"{self.subdir}/{self.__name}")
#      82     except LookupError as e:
#      83         try:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\nltk\data.py:583, in find(resource_name, paths)
#     581 sep = "*" * 70
#     582 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/stopwords
#
#   Searched in:
#     - 'C:\\Users\\msi/nltk_data'
#     - 'c:\\Program Files\\Python311\\nltk_data'
#     - 'c:\\Program Files\\Python311\\share\\nltk_data'
#     - 'c:\\Program Files\\Python311\\lib\\nltk_data'
#     - 'C:\\Users\\msi\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Error loading stopwords: <urlopen error [WinError 10060] A
# [nltk_data]     connection attempt failed because the connected party
# [nltk_data]     did not properly respond after a period of time, or
# [nltk_data]     established connection failed because connected host
# [nltk_data]     has failed to respond>
# False
